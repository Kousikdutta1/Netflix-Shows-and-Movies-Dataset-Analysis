# %% [markdown]
# <a href="https://colab.research.google.com/github/Kousikdutta1/Netflix-Shows-and-Movies-Dataset-Analysis/blob/main/Netflix_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **NAME OF THE DATASET: NETFLIX DATASET**

# %% [markdown]
# **Netflix is the largest online movie and TV show streaming service on the planet. Its service is widely
# available in many countries. The service was first introduced as a DVD rental service on the Internet and later, the founder
# and CEO of the company Reed Hastings transitioned to a revolutionary way of delivering movies and TV
# shows through its website allowing many users to directly stream their favorite contents on their Internetenabled devices including desktop computers, laptops, tablet PCs, mobile phones, and many more. With
# its a whole new approach of delivering shows and movies, the sales of Netflix went up exponentially. Since
# then, the platform created its own recommender system to understand what types of movies and TV shows
# the users would like to watch, what kind of style of cinematography they liked the most, and how they consume their favorite TV shows. Many users tend to spend most of their time watching shows and movies on Netflix.**

# %% [markdown]
# #**Objective of This Project -**

# %% [markdown]
# *   Understand the dataset, data types & missing values.
# *   Clean the dataset and handle the missing values.
# *   Through Data visualization get some conclusions.

# %%
# Import the necessary libraries

import numpy as np  # Helps in working with matrices and arrays
import pandas as pd # Helps in reading the datset , making dataframe and manipulating dataframes
import matplotlib.pyplot as plt  # Helps to visualize the dataset
import seaborn as sns  # Helps to visualize the dataset

# %matplotlib inline

# %%
# Let's Import the Dataset

netflix_data_file_path = "/content/drive/MyDrive/Colab Notebooks/Netflix Titles Dataset Exploratory Analysis/netflix_titles.csv"
netflix_df = pd.read_csv(netflix_data_file_path)

# %% [markdown]
# ## Let's display Top 10 rows, last 10 rows, Column names, Shape, Null values and Data types of the Netflix Dataset.

# %%
# Let's check top 10 rows of the datset

netflix_df.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
#                                                 cast  \
# 0                                                NaN
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                                NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...
# 6  Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9  Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
#
#                                              country          date_added  \
# 0                                      United States  September 25, 2021
# 1                                       South Africa  September 24, 2021
# 2                                                NaN  September 24, 2021
# 3                                                NaN  September 24, 2021
# 4                                              India  September 24, 2021
# 5                                                NaN  September 24, 2021
# 6                                                NaN  September 24, 2021
# 7  United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 8                                     United Kingdom  September 24, 2021
# 9                                      United States  September 24, 2021
#
#    release_year rating   duration  \
# 0          2020  PG-13     90 min
# 1          2021  TV-MA  2 Seasons
# 2          2021  TV-MA   1 Season
# 3          2021  TV-MA   1 Season
# 4          2021  TV-MA  2 Seasons
# 5          2021  TV-MA   1 Season
# 6          2021     PG     91 min
# 7          1993  TV-MA    125 min
# 8          2021  TV-14  9 Seasons
# 9          2021  PG-13    104 min
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
# 5                 TV Dramas, TV Horror, TV Mysteries
# 6                           Children & Family Movies
# 7   Dramas, Independent Movies, International Movies
# 8                       British TV Shows, Reality TV
# 9                                   Comedies, Dramas
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...
# 5  The arrival of a charismatic young priest brin...
# 6  Equestria's divided. But a bright-eyed hero be...
# 7  On a photo shoot in Ghana, an American model s...
# 8  A talented batch of amateur bakers face off in...
# 9  A woman adjusting to life after a loss contend...

# %%
# Let's check last 10 rows of the datset

netflix_df.tail(10)
# Out:
#      show_id     type               title                 director  \
# 8797   s8798  TV Show           Zak Storm                      NaN
# 8798   s8799    Movie            Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800    Movie               Zenda           Avadhoot Gupte
# 8800   s8801  TV Show  Zindagi Gulzar Hai                      NaN
# 8801   s8802    Movie             Zinzana          Majid Al Ansari
# 8802   s8803    Movie              Zodiac            David Fincher
# 8803   s8804  TV Show         Zombie Dumb                      NaN
# 8804   s8805    Movie          Zombieland          Ruben Fleischer
# 8805   s8806    Movie                Zoom             Peter Hewitt
# 8806   s8807    Movie              Zubaan              Mozez Singh
#
#                                                    cast  \
# 8797  Michael Johnston, Jessica Gee-George, Christin...
# 8798  Adil Hussain, Mona Singh, K.K. Raina, Sanjay M...
# 8799  Santosh Juvekar, Siddharth Chandekar, Sachit P...
# 8800  Sanam Saeed, Fawad Khan, Ayesha Omer, Mehreen ...
# 8801  Ali Suliman, Saleh Bakri, Yasa, Ali Al-Jabri, ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8803                                                NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
#
#                                             country          date_added  \
# 8797  United States, France, South Korea, Indonesia  September 13, 2018
# 8798                                          India   December 31, 2019
# 8799                                          India   February 15, 2018
# 8800                                       Pakistan   December 15, 2016
# 8801                   United Arab Emirates, Jordan       March 9, 2016
# 8802                                  United States   November 20, 2019
# 8803                                            NaN        July 1, 2019
# 8804                                  United States    November 1, 2019
# 8805                                  United States    January 11, 2020
# 8806                                          India       March 2, 2019
#
#       release_year rating   duration  \
# 8797          2016  TV-Y7  3 Seasons
# 8798          2014  TV-MA    131 min
# 8799          2009  TV-14    120 min
# 8800          2012  TV-PG   1 Season
# 8801          2015  TV-MA     96 min
# 8802          2007      R    158 min
# 8803          2018  TV-Y7  2 Seasons
# 8804          2009      R     88 min
# 8805          2006     PG     88 min
# 8806          2015  TV-14    111 min
#
#                                               listed_in  \
# 8797                                           Kids' TV
# 8798             Comedies, Dramas, International Movies
# 8799                       Dramas, International Movies
# 8800  International TV Shows, Romantic TV Shows, TV ...
# 8801            Dramas, International Movies, Thrillers
# 8802                     Cult Movies, Dramas, Thrillers
# 8803             Kids' TV, Korean TV Shows, TV Comedies
# 8804                            Comedies, Horror Movies
# 8805                 Children & Family Movies, Comedies
# 8806     Dramas, International Movies, Music & Musicals
#
#                                             description
# 8797  Teen surfer Zak Storm is mysteriously transpor...
# 8798  A philandering small-town mechanic's political...
# 8799  A change in the leadership of a political part...
# 8800  Strong-willed, middle-class Kashaf and carefre...
# 8801  Recovering alcoholic Talal wakes up inside a s...
# 8802  A political cartoonist, a crime reporter and a...
# 8803  While living alone in a spooky town, a young g...
# 8804  Looking to survive in a world taken over by zo...
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...

# %%
# Let's check random 10 rows of the datset

netflix_df.sample(10)
# Out:
#      show_id     type                                            title  \
# 5623   s5624    Movie                                     Semana Santa
# 8111   s8112    Movie                                       Submission
# 2862   s2863    Movie                                Pop, Lock 'n Roll
# 2236   s2237    Movie              Little Singham: Legend of Dugabakka
# 7675   s7676  TV Show                               Operation Proposal
# 5197   s5198    Movie  The B-Side: Elsa Dorfman's Portrait Photography
# 888     s889    Movie                     The Upshaws - The Afterparty
# 6675   s6676    Movie                                           El Che
# 2039   s2040    Movie                                       Toll Booth
# 6529   s6530    Movie                                    Consequences
#
#                       director  \
# 5623  Alejandra Márquez Abella
# 8111              J.M. Berrios
# 2862             Ziggy Hofmeyr
# 2236                       NaN
# 7675                       NaN
# 5197              Errol Morris
# 888                        NaN
# 6675          Matías Gueilburt
# 2039           Tolga Karaçelik
# 6529              Ozan Açıktan
#
#                                                    cast        country  \
# 5623  Tenoch Huerta, Anajosé Aldrete, Esteban Ávila,...         Mexico
# 8111  Scott Pryor, Darrin Dewitt Henson, Eric Robert...  United States
# 2862  Maurice Paige, Yasirah Bhelz, Lionel Newton, T...   South Africa
# 2236                                                NaN            NaN
# 7675  Seung-ho Yoo, Eun-bin Park, Kyung-pyo Go, Ye-w...    South Korea
# 5197                                       Elsa Dorfman  United States
# 888   David Spade, London Hughes, Fortune Feimster, ...            NaN
# 6675                              Paco Ignacio Taibo II      Venezuela
# 2039  Büşra Pekin, Nur Aysan, Ruhi Sarı, Nergis Öztü...         Turkey
# 6529  Nehir Erdoğan, Tardu Flordun, İlker Kaleli, Se...         Turkey
#
#              date_added  release_year rating  duration  \
# 5623   January 31, 2017          2015  TV-MA    87 min
# 8111  November 11, 2019          2019  TV-MA    95 min
# 2862      March 1, 2020          2017  TV-14    88 min
# 2236      July 15, 2020          2020  TV-Y7    68 min
# 7675       July 1, 2016          2012  TV-PG  1 Season
# 5197   October 31, 2017          2016      R    76 min
# 888        May 14, 2021          2021  TV-14    32 min
# 6675   October 15, 2017          2017  TV-14   119 min
# 2039  September 7, 2020          2010  TV-MA    98 min
# 6529   October 25, 2019          2014  TV-MA   106 min
#
#                                               listed_in  \
# 5623                       Dramas, International Movies
# 8111                         Action & Adventure, Dramas
# 2862      Dramas, International Movies, Romantic Movies
# 2236                 Children & Family Movies, Comedies
# 7675  International TV Shows, Korean TV Shows, Roman...
# 5197                                      Documentaries
# 888                                            Comedies
# 6675                Documentaries, International Movies
# 2039   Dramas, Independent Movies, International Movies
# 6529            Dramas, International Movies, Thrillers
#
#                                             description
# 5623  A single mother, her boyfriend and her 8-year-...
# 8111  After a near-death trip home, a Marine looking...
# 2862  An ambitious hip-hop dancer jeopardizes his ri...
# 2236  As fears rise over a ghost known for nighttime...
# 7675  On Yi-seul's wedding day, her friend Baek-ho w...
# 5197  Filmmaker Errol Morris probes the life, work a...
# 888   The comedic dream team from "The Upshaws" disc...
# 6675  Spanish-Mexican writer Paco Ignacio Taibo II h...
# 2039  A toll booth operator's mundane life is upende...
# 6529  Secrets bubble to the surface after a sensual ...

# %%
# Let's check the number of rows and columns present in the dataset.

netflix_df.shape
# Out:
# (8807, 12)

# %%
# Let's check the column names

netflix_df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
# Checking the information about all the columns like Datatypes, Null and Non null values.

netflix_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# **As we can see from the above information that null values are present in column director, cast, country, date_added, rating, duration.**

# %%
# Descriptive Statistics 

netflix_df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %% [markdown]
# **As we can see we have only one Integer column which is Release Year , thats why we have got stats for that column only**

# %%
# Let's check the null values of the dataset and change the datatype of any column if needed.

netflix_df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# **As we can see from the above information
# that**
#
# **Following do not require any fills**
#
#
# *   Show id
# *   Type
# *   Title
# *   release_year
# *   listed_in
# *   Description
#
# **Following are missing data**
#
# *  director
# *  cast
# *  country
# *  date_added
# *  rating
# *  duration

# %%
# Let's convert the datatype of Date_added to Datetime

netflix_df['date_added'] = pd.to_datetime (netflix_df['date_added'])

# %%
# Let's check if the date_added datatype changed or not

netflix_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   datetime64[ns]
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 825.8+ KB

# %% [markdown]
# **We have successfully changed the datatype of date_added**

# %%
# Let's see the dataset with changed 'date' datatype

netflix_df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# 3 2021-09-24          2021  TV-MA   1 Season
# 4 2021-09-24          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...
